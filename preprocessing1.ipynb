# %% [markdown]
# # ***Assingnment on preprocessing***

# %% [markdown]
# 1.	***Load the dataset into python environment***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"/content/titanic_dataset.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2.	***Make PassengerId as the index column***

# %%
data=pd.read_csv(r"/content/titanic_dataset.csv",index_col="PassengerId")
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# 3.	**Check the basic details of the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.shape
# Out:
# (891, 11)

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Here name is not a relevent feature for prediction and cabin contain majority of null values
data.drop(["Name","Cabin"],axis=1,inplace=True)

# %%
data.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# PassengerId
# 1                   0       3    male  22.0      1      0         A/5 21171
# 2                   1       1  female  38.0      1      0          PC 17599
# 3                   1       3  female  26.0      0      0  STON/O2. 3101282
# 4                   1       1  female  35.0      1      0            113803
# 5                   0       3    male  35.0      0      0            373450
#
#                 Fare Embarked
# PassengerId
# 1             7.2500        S
# 2            71.2833        C
# 3             7.9250        S
# 4            53.1000        S
# 5             8.0500        S

# %%
data.drop("Embarked",axis=1,inplace=True)

# %%
data.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# PassengerId
# 1                   0       3    male  22.0      1      0         A/5 21171
# 2                   1       1  female  38.0      1      0          PC 17599
# 3                   1       3  female  26.0      0      0  STON/O2. 3101282
# 4                   1       1  female  35.0      1      0            113803
# 5                   0       3    male  35.0      0      0            373450
#
#                 Fare
# PassengerId
# 1             7.2500
# 2            71.2833
# 3             7.9250
# 4            53.1000
# 5             8.0500

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare'], dtype='object')

# %%
num=['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
corr_matrix=data[num].corr()

# %%
sns.heatmap(corr_matrix,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
from scipy.stats import chi2_contingency
contingency=pd.crosstab(data["Sex"],data["Survived"])
p=chi2_contingency(contingency)
print("p-value",p)
# here p value is very small compared to alpha . sex is higly correlated with target
# Out:
# p-value Chi2ContingencyResult(statistic=260.71702016732104, pvalue=1.1973570627755645e-58, dof=1, expected_freq=array([[193.47474747, 120.52525253],
#        [355.52525253, 221.47474747]]))

# %%
from scipy.stats import chi2_contingency
contingency=pd.crosstab(data["Ticket"],data["Survived"])
p=chi2_contingency(contingency)
print("p-value",p)
# Out:
# p-value Chi2ContingencyResult(statistic=766.5697029458893, pvalue=0.01152729601163775, dof=680, expected_freq=array([[1.84848485, 1.15151515],
#        [1.84848485, 1.15151515],
#        [1.23232323, 0.76767677],
#        ...,
#        [0.61616162, 0.38383838],
#        [0.61616162, 0.38383838],
#        [1.23232323, 0.76767677]]))

# %%
sns.histplot(data["Age"],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# 4.**filling the missing values**

# %%
data["Age"]=data["Age"].fillna(data["Age"].mean())

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# dtype: int64

# %% [markdown]
# 5.**Checking for outliers**

# %%
sns.boxplot(data["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(data["Pclass"])
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.boxplot(data["SibSp"])
# Out:
# <Axes: ylabel='SibSp'>

# %%
sns.boxplot(data["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
# we can't drop the outliers because  they are true values and relevent for the prediction of the target variable survived

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["Sex"]=le.fit_transform(data["Sex"])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["Ticket"]=le.fit_transform(data["Ticket"])

# %%
data.head()
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare
# PassengerId
# 1                   0       3    1  22.0      1      0     523   7.2500
# 2                   1       1    0  38.0      1      0     596  71.2833
# 3                   1       3    0  26.0      0      0     669   7.9250
# 4                   1       1    0  35.0      1      0      49  53.1000
# 5                   0       3    1  35.0      0      0     472   8.0500

# %%
x=data.drop("Survived",axis=1)
y=data["Survived"]

# %%
x.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch  Ticket     Fare
# PassengerId
# 1                 3    1  22.0      1      0     523   7.2500
# 2                 1    0  38.0      1      0     596  71.2833
# 3                 3    0  26.0      0      0     669   7.9250
# 4                 1    0  35.0      1      0      49  53.1000
# 5                 3    1  35.0      0      0     472   8.0500

# %%
y.head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %% [markdown]
# 6.**Apply MinMaxScaling on the feature set**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=scaler.fit_transform(x)

# %%
x=pd.DataFrame(x,columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare'])

# %%
x.head()
# Out:
#    Pclass  Sex       Age  SibSp  Parch    Ticket      Fare
# 0     1.0  1.0  0.271174  0.125    0.0  0.769118  0.014151
# 1     0.0  0.0  0.472229  0.125    0.0  0.876471  0.139136
# 2     1.0  0.0  0.321438  0.000    0.0  0.983824  0.015469
# 3     0.0  0.0  0.434531  0.125    0.0  0.072059  0.103644
# 4     1.0  1.0  0.434531  0.000    0.0  0.694118  0.015713

# %%
data=pd.concat([y,x],axis=1)

# %%
y.head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
data.head()
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch    Ticket      Fare
# 1       0.0     0.0  0.0  0.472229  0.125    0.0  0.876471  0.139136
# 2       1.0     1.0  0.0  0.321438  0.000    0.0  0.983824  0.015469
# 3       1.0     0.0  0.0  0.434531  0.125    0.0  0.072059  0.103644
# 4       1.0     1.0  1.0  0.434531  0.000    0.0  0.694118  0.015713
# 5       0.0     1.0  1.0  0.367921  0.000    0.0  0.404412  0.016510
